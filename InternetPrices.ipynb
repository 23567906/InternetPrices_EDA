# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\PRIYAMVADA\Downloads\all_csv sorted.csv")

# %%
df
# Out:
#      S.NO Country code                           Country  Continental region  \
# 0       0           IL                            Israel           NEAR EAST
# 1       1           KG                        Kyrgyzstan   CIS (FORMER USSR)
# 2       2           FJ                              Fiji             OCEANIA
# 3       3           IT                             Italy      WESTERN EUROPE
# 4       4           SD                             Sudan  SUB-SAHARAN AFRICA
# ..    ...          ...                               ...                 ...
# 237   239           VA           Vatican City (Holy See)              Europe
# 238   240           VE                         Venezuela       SOUTH AMERICA
# 239   241           WF                 Wallis and Futuna             OCEANIA
# 240   242           CD  Democratic Republic of the Congo  SUB-SAHARAN AFRICA
# 241   243           ZW                          Zimbabwe  SUB-SAHARAN AFRICA
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 13 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   S.NO                                              242 non-null    int64
#  1   Country code                                      242 non-null    object
#  2   Country                                           242 non-null    object
#  3   Continental region                                242 non-null    object
#  4   NO. OF Internet Plans                             231 non-null    float64
#  5   Average price of 1GB (USD)                        242 non-null    object
#  6   Cheapest 1GB for 30 days (USD)                    231 non-null    float64
#  7   Most expensive 1GB (USD)                          231 non-null    float64
#  8   Average price of 1GB (USD  at the start of 2021)  231 non-null    object
# ...

# %%
df.describe()
# Out:
#              S.NO  NO. OF Internet Plans  Cheapest 1GB for 30 days (USD)  \
# count  242.000000             231.000000                      231.000000
# mean   120.756198              26.610390                        1.718442
# std     70.381020              16.457446                        4.764523
# min      0.000000               1.000000                        0.000000
# 25%     60.250000              15.000000                        0.215000
# 50%    120.500000              22.000000                        0.630000
# 75%    180.750000              36.000000                        1.370000
# max    243.000000              60.000000                       45.160000
#
#        Most expensive 1GB (USD)  Avg \n(Mbit/s)Ookla
# count                231.000000           141.000000
# mean                  29.664848            37.275674
# std                   59.235115            28.669584
# min                    0.630000             4.890000
# ...

# %%
df.columns
# Out:
# Index(['S.NO', 'Country code', 'Country', 'Continental region',
#        'NO. OF Internet Plans', 'Average price of 1GB (USD)',
#        'Cheapest 1GB for 30 days (USD)', 'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)', 'Internet users',
#        'Population', 'Avg \n(Mbit/s)Ookla'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 13 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   S.NO                                              242 non-null    int64
#  1   Country code                                      242 non-null    object
#  2   Country                                           242 non-null    object
#  3   Continental region                                242 non-null    object
#  4   NO. OF Internet Plans                             231 non-null    float64
#  5   Average price of 1GB (USD)                        242 non-null    object
#  6   Cheapest 1GB for 30 days (USD)                    231 non-null    float64
#  7   Most expensive 1GB (USD)                          231 non-null    float64
#  8   Average price of 1GB (USD  at the start of 2021)  231 non-null    object
# ...

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['NO. OF Internet Plans'],df['Cheapest 1GB for 30 days (USD)'])
plt.xlabel("NO. OF Internet Plans")
plt.ylabel("Cheapest 1GB for 30 days (USD)")
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['NO. OF Internet Plans'],df['Most expensive 1GB (USD)'])
plt.xlabel("NO. OF Internet Plans")
plt.ylabel("Most expensive 1GB (USD)")
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['NO. OF Internet Plans'],df['Avg \n(Mbit/s)Ookla'])
plt.xlabel("NO. OF Internet Plans")
plt.ylabel("Avg \n(Mbit/s)Ookla")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n{}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['S.NO', 'Country code', 'Country', 'Continental region',
#        'NO. OF Internet Plans', 'Average price of 1GB (USD)',
#        'Cheapest 1GB for 30 days (USD)', 'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)', 'Internet users',
#        'Population', 'Avg \n(Mbit/s)Ookla'],
#       dtype='object')

# %%
columns_plot=[ 'NO. OF Internet Plans', 'Cheapest 1GB for 30 days (USD)', 
              'Most expensive 1GB (USD)',  'Avg \n(Mbit/s)Ookla']
for i in columns_plot:
    bar_plot(i)
# Out:
# NO. OF Internet Plans:
# NO. OF Internet Plans
# 60.0    20
# 18.0    11
# 17.0    11
# 21.0    10
# 9.0      9
# 22.0     9
# 42.0     8
# 13.0     8
# 35.0     7
# 19.0     7
# 14.0     7
# 27.0     6
# 24.0     6
# 20.0     6
# 11.0     6
# 15.0     6
# 25.0     5
# 16.0     5
# 23.0     5
# 3.0      4
# 7.0      4
# 12.0     4
# 30.0     4
# 4.0      4
# 45.0     4
# 34.0     4
# 58.0     3
# 36.0     3
# 2.0      3
# 40.0     3
# 28.0     3
# 52.0     3
# 33.0     2
# 31.0     2
# 37.0     2
# 8.0      2
# 32.0     2
# 5.0      2
# 29.0     2
# 6.0      2
# 46.0     2
# 44.0     2
# 59.0     1
# 54.0     1
# 48.0     1
# 50.0     1
# 26.0     1
# 38.0     1
# 47.0     1
# 49.0     1
# 53.0     1
# 39.0     1
# 10.0     1
# 51.0     1
# 1.0      1
# Name: count, dtype: int64
# Cheapest 1GB for 30 days (USD):
# Cheapest 1GB for 30 days (USD)
# 0.24     6
# 0.02     5
# 1.00     5
# 0.10     4
# 0.33     4
#         ..
# 0.73     1
# 1.84     1
# 0.71     1
# 1.78     1
# ...

# %%
df.columns
# Out:
# Index(['S.NO', 'Country code', 'Country', 'Continental region',
#        'NO. OF Internet Plans', 'Average price of 1GB (USD)',
#        'Cheapest 1GB for 30 days (USD)', 'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)', 'Internet users',
#        'Population', 'Avg \n(Mbit/s)Ookla'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 13 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   S.NO                                              242 non-null    int64
#  1   Country code                                      242 non-null    object
#  2   Country                                           242 non-null    object
#  3   Continental region                                242 non-null    object
#  4   NO. OF Internet Plans                             231 non-null    float64
#  5   Average price of 1GB (USD)                        242 non-null    object
#  6   Cheapest 1GB for 30 days (USD)                    231 non-null    float64
#  7   Most expensive 1GB (USD)                          231 non-null    float64
#  8   Average price of 1GB (USD  at the start of 2021)  231 non-null    object
# ...

# %%
df['Average price of 1GB (USD)'].unique()
# Out:
# array(['0.05', '0.15', '0.19', '0.27', '0.29', '0.32', '0.34', '0.38',
#        '0.39', '0.41', '0.42', '0.43', '0.49', '0.51', '0.52', '0.56',
#        '0.59', '0.6', '0.61', '0.63', '0.64', '0.66', '0.68', '0.7',
#        '0.74', '0.75', '0.76', '0.78', '0.79', '0.81', '0.82', '0.83',
#        '0.85', '0.88', '0.89', '0.9', '0.92', '0.94', '0.96', '0.97',
#        '1.02', '1.04', '1.06', '1.08', '1.09', '1.12', '1.13', '1.14',
#        '1.15', '1.17', '1.18', '1.23', '1.24', '1.25', '1.28', '1.3',
#        '1.32', '1.33', '1.38', '1.39', '1.41', '1.42', '1.45', '1.46',
#        '1.47', '1.51', '1.52', '1.56', '1.58', '1.61', '1.67', '1.7',
#        '1.71', '1.72', '1.76', '1.77', '1.8', '1.82', '1.9', '1.93',
#        '1.94', '1.99', '2', '2.01', '2.1', '2.12', '2.14', '2.15', '2.18',
#        '2.23', '2.24', '2.25', '2.26', '2.3', '2.35', '2.36', '2.38',
#        '2.39', '2.41', '2.44', '2.53', '2.58', '2.59', '2.6', '2.62',
# ...

# %%
target_elements='NO PROVIDERS'
mask=df['Average price of 1GB (USD)'] != target_elements
df=df[mask]

# %%
df['Average price of 1GB (USD)']=df['Average price of 1GB (USD)'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df['Average price of 1GB (USD)']=df['Average price of 1GB (USD)'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
target_element='HYPERINFLATION'
mask=df['Average price of 1GB (USD)'] != target_element
df=df[mask]

# %%
df['Average price of 1GB (USD)']=df['Average price of 1GB (USD)'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df['Average price of 1GB (USD)']=df['Average price of 1GB (USD)'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
target_element="Prices listed in non-convertible 'units'"
mask=df['Average price of 1GB (USD)'] != target_element
df=df[mask]

# %%
df['Average price of 1GB (USD)']=df['Average price of 1GB (USD)'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df['Average price of 1GB (USD)']=df['Average price of 1GB (USD)'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
target_element='UNRELIABLE EXCHANGE RATES'
mask=df['Average price of 1GB (USD)'] != target_element
df=df[mask]

# %%
df['Average price of 1GB (USD)']=df['Average price of 1GB (USD)'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 231 entries, 0 to 230
# Data columns (total 13 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   S.NO                                              231 non-null    int64
#  1   Country code                                      231 non-null    object
#  2   Country                                           231 non-null    object
#  3   Continental region                                231 non-null    object
#  4   NO. OF Internet Plans                             231 non-null    float64
#  5   Average price of 1GB (USD)                        231 non-null    float64
#  6   Cheapest 1GB for 30 days (USD)                    231 non-null    float64
#  7   Most expensive 1GB (USD)                          231 non-null    float64
#  8   Average price of 1GB (USD  at the start of 2021)  231 non-null    object
# ...

# %%
df['Average price of 1GB (USD  at the start of 2021)'].unique()
# Out:
# array(['0.11', '0.21', '0.59', '0.43', '0.63', '0.52', '1.12', '0.7',
#        '0.51', '0.71', '0.81', '0.64', '0.89', '1.16', '0.57', '0.65',
#        '0.61', '10.86', '0.69', '0.46', '1.34', '0.5', '0.74', '0.86',
#        '0.72', '0.94', '0.09', '0.68', '4.73', '0.73', '2.48', '1.05',
#        '0.78', '0.8', '0.77', '1.08', '1.5', '2.74', '1.39', '0.99',
#        '2.42', '2.75', '1.01', '3.3', '1.71', '1.75', '2.14', '1.55',
#        '1.09', '3.24', '1.23', '0.98', '1.37', '2.47', '1.36', '4.2',
#        '2.13', '1.03', '1.46', '1.81', '1.48', '3.41', '1.6', '1.45',
#        '1.85', '1.27', '2.07', '1.24', '2.12', '1.58', '0.75', '1.62',
#        '3.12', '3.61', '5.29', '2.5', '2.08', '5.32', '3.26', '2.44',
#        '4.92', '1.42', '0.93', '1.66', '1.86', '5.92', '2.89', '2.17',
#        '4.67', '3.62', '2.27', '4.58', '3.94', '2', '2.65', '5.09',
#        '2.64', '13.31', '5.4', '2.22', '2.55', '4.06', '3.04', '3.33',
# ...

# %%
target_element='NO PACKAGES'
mask=df['Average price of 1GB (USD)'] != target_element
df=df[mask]

# %%
df['Average price of 1GB (USD  at the start of 2021)']=df['Average price of 1GB (USD  at the start of 2021)'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df['Average price of 1GB (USD  at the start of 2021)']=df['Average price of 1GB (USD  at the start of 2021)'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df['Average price of 1GB (USD  at the start of 2021)'].unique()
# Out:
# array(['0.11', '0.21', '0.59', '0.43', '0.63', '0.52', '1.12', '0.7',
#        '0.51', '0.71', '0.81', '0.64', '0.89', '1.16', '0.57', '0.65',
#        '0.61', '10.86', '0.69', '0.46', '1.34', '0.5', '0.74', '0.86',
#        '0.72', '0.94', '0.09', '0.68', '4.73', '0.73', '2.48', '1.05',
#        '0.78', '0.8', '0.77', '1.08', '1.5', '2.74', '1.39', '0.99',
#        '2.42', '2.75', '1.01', '3.3', '1.71', '1.75', '2.14', '1.55',
#        '1.09', '3.24', '1.23', '0.98', '1.37', '2.47', '1.36', '4.2',
#        '2.13', '1.03', '1.46', '1.81', '1.48', '3.41', '1.6', '1.45',
#        '1.85', '1.27', '2.07', '1.24', '2.12', '1.58', '0.75', '1.62',
#        '3.12', '3.61', '5.29', '2.5', '2.08', '5.32', '3.26', '2.44',
#        '4.92', '1.42', '0.93', '1.66', '1.86', '5.92', '2.89', '2.17',
#        '4.67', '3.62', '2.27', '4.58', '3.94', '2', '2.65', '5.09',
#        '2.64', '13.31', '5.4', '2.22', '2.55', '4.06', '3.04', '3.33',
# ...

# %%
target_element='NO PACKAGES'
mask=df['Average price of 1GB (USD  at the start of 2021)'] != target_element
df=df[mask]

# %%
df['Average price of 1GB (USD  at the start of 2021)']=df['Average price of 1GB (USD  at the start of 2021)'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229 entries, 0 to 230
# Data columns (total 13 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   S.NO                                              229 non-null    int64
#  1   Country code                                      229 non-null    object
#  2   Country                                           229 non-null    object
#  3   Continental region                                229 non-null    object
#  4   NO. OF Internet Plans                             229 non-null    float64
#  5   Average price of 1GB (USD)                        229 non-null    float64
#  6   Cheapest 1GB for 30 days (USD)                    229 non-null    float64
#  7   Most expensive 1GB (USD)                          229 non-null    float64
#  8   Average price of 1GB (USD  at the start of 2021)  229 non-null    float64
# ...

# %%
df['Internet users'].unique()
# Out:
# array(['6,788,737', '2,309,235', '452,479', '50,540,000', '12,512,639',
#        '124,000,000', '3,083,783', '129,180,000', '7,121,116',
#        '14,864,456', '59,470,000', '196,000,000', '7,048,231', '20,100',
#        '68,172,134', '26,350,000', '1,010,740,000', '66,023',
#        '118,800,000', '13,913,699', '16,692,456', '294,851', '729,236',
#        '16,190,000', '69,945,905', '34,697,848', '15,065,541',
#        '833,710,000', '21,159,515', '1,387,116', '31,100,000',
#        '30,000,000', '702,911', nan, '2,043,110', '16,374,103',
#        '5,407,278', '4,053,797', '5,441,827', '388,541', '1,353,986',
#        '136,203,231', '22,072,765', '25,343,685', '5,580,465',
#        '160,010,801', '4,698,108', '1,732,218', '1,589,659', '4,831,170',
#        '4,068,194', '54,740,141', '9,521,056', '54,043,108', '37,553',
#        '6,400,330', '4,821,119', '532,849', '4,760,715', '18,892,351',
#        '15,674,241', '7,681,957', '12,545,558', '329,196', '42,400,756',
# ...

# %%
df['Internet users']=df['Internet users'].str.replace(',','').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229 entries, 0 to 230
# Data columns (total 13 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   S.NO                                              229 non-null    int64
#  1   Country code                                      229 non-null    object
#  2   Country                                           229 non-null    object
#  3   Continental region                                229 non-null    object
#  4   NO. OF Internet Plans                             229 non-null    float64
#  5   Average price of 1GB (USD)                        229 non-null    float64
#  6   Cheapest 1GB for 30 days (USD)                    229 non-null    float64
#  7   Most expensive 1GB (USD)                          229 non-null    float64
#  8   Average price of 1GB (USD  at the start of 2021)  229 non-null    float64
# ...

# %%
df['Population'].unique()
# Out:
# array(['8,381,516', '6,304,030', '883,483', '60,627,291', '41,801,533',
#        '145,734,038', '4,051,944', '166,303,498', '21,228,763',
#        '18,729,160', '64,990,511', '267,670,543', '9,452,617', '33,785',
#        '95,545,962', '42,228,408', '1,427,647,786', '196,129',
#        '213,756,286', '18,319,618', '32,476,244', '15,008,226',
#        '3,170,216', '28,095,714', '82,340,088', '37,921,592',
#        '29,767,102', '1,352,642,280', '24,898,152', '6,678,559',
#        '44,246,156', '56,313,438', '1,267,185', nan, '2,951,745',
#        '53,708,320', '5,752,126', '4,137,312', '16,249,792', '754,388',
#        '11,123,178', '195,874,685', '36,029,093', '31,528,033',
#        '25,216,267', '209,469,323', '15,854,323', '6,465,501',
#        '2,082,957', '5,522,576', '37,171,921', '98,423,598', '17,084,358',
#        '69,428,453', '38,682', '11,565,201', '5,757,499', '958,923',
#        '17,351,708', '38,433,600', '31,989,260', '8,891,388',
# ...

# %%
df['Population']=df['Population'].str.replace(',','').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229 entries, 0 to 230
# Data columns (total 13 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   S.NO                                              229 non-null    int64
#  1   Country code                                      229 non-null    object
#  2   Country                                           229 non-null    object
#  3   Continental region                                229 non-null    object
#  4   NO. OF Internet Plans                             229 non-null    float64
#  5   Average price of 1GB (USD)                        229 non-null    float64
#  6   Cheapest 1GB for 30 days (USD)                    229 non-null    float64
#  7   Most expensive 1GB (USD)                          229 non-null    float64
#  8   Average price of 1GB (USD  at the start of 2021)  229 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['S.NO', 'Country code', 'Country', 'Continental region',
#        'NO. OF Internet Plans', 'Average price of 1GB (USD)',
#        'Cheapest 1GB for 30 days (USD)', 'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)', 'Internet users',
#        'Population', 'Avg \n(Mbit/s)Ookla'],
#       dtype='object')

# %%
df.drop(labels=['Country code', 'Country', 'Continental region'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229 entries, 0 to 230
# Data columns (total 10 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   S.NO                                              229 non-null    int64
#  1   NO. OF Internet Plans                             229 non-null    float64
#  2   Average price of 1GB (USD)                        229 non-null    float64
#  3   Cheapest 1GB for 30 days (USD)                    229 non-null    float64
#  4   Most expensive 1GB (USD)                          229 non-null    float64
#  5   Average price of 1GB (USD  at the start of 2021)  229 non-null    float64
#  6   Average price of 1GB (USD – at start of 2020)     229 non-null    object
#  7   Internet users                                    204 non-null    float64
#  8   Population                                        202 non-null    float64
# ...

# %%
df.head()
# Out:
#    S.NO  NO. OF Internet Plans  Average price of 1GB (USD)  \
# 0     0                   27.0                        0.05
# 1     1                   20.0                        0.15
# 2     2                   18.0                        0.19
# 3     3                   29.0                        0.27
# 4     4                   33.0                        0.27
#
#    Cheapest 1GB for 30 days (USD)  Most expensive 1GB (USD)  \
# 0                            0.02                     20.95
# 1                            0.10                      7.08
# 2                            0.05                      0.85
# 3                            0.09                      3.54
# 4                            0.03                      0.92
#
#    Average price of 1GB (USD  at the start of 2021)  \
# 0                                              0.11
# 1                                              0.21
# 2                                              0.59
# ...

# %%
df.columns
# Out:
# Index(['S.NO', 'NO. OF Internet Plans', 'Average price of 1GB (USD)',
#        'Cheapest 1GB for 30 days (USD)', 'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)', 'Internet users',
#        'Population', 'Avg \n(Mbit/s)Ookla'],
#       dtype='object')

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['NO. OF Internet Plans'],df['Average price of 1GB (USD)'])
plt.xlabel("NO. OF Internet Plans")
plt.ylabel("Average price of 1GB (USD)")
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['NO. OF Internet Plans'],df['Cheapest 1GB for 30 days (USD)'])
plt.xlabel("NO. OF Internet Plans")
plt.ylabel("Cheapest 1GB for 30 days (USD)")
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['NO. OF Internet Plans'],df['Internet users'])
plt.xlabel("NO. OF Internet Plans")
plt.ylabel("Internet users")
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['Average price of 1GB (USD)'],df['Cheapest 1GB for 30 days (USD)'])
plt.xlabel("Average price of 1GB (USD")
plt.ylabel("Cheapest 1GB for 30 days (USD)")
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['NO. OF Internet Plans'],df['Most expensive 1GB (USD)'])
plt.xlabel("NO. OF Internet Plans")
plt.ylabel("Most expensive 1GB (USD)")
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['NO. OF Internet Plans'],df['Average price of 1GB (USD  at the start of 2021)'])
plt.xlabel("NO. OF Internet Plans")
plt.ylabel("Average price of 1GB (USD  at the start of 2021)")
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['NO. OF Internet Plans'],df['Internet users'])
plt.xlabel("NO. OF Internet Plans")
plt.ylabel("Internet users")
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['NO. OF Internet Plans'],df['Avg \n(Mbit/s)Ookla'])
plt.xlabel("NO. OF Internet Plans")
plt.ylabel("Avg \n(Mbit/s)Ookla")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n{}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['S.NO', 'NO. OF Internet Plans', 'Average price of 1GB (USD)',
#        'Cheapest 1GB for 30 days (USD)', 'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)', 'Internet users',
#        'Population', 'Avg \n(Mbit/s)Ookla'],
#       dtype='object')

# %%
columns_plot=['NO. OF Internet Plans', 'Average price of 1GB (USD)',
       'Cheapest 1GB for 30 days (USD)', 'Most expensive 1GB (USD)',
       'Average price of 1GB (USD  at the start of 2021)',
       'Average price of 1GB (USD – at start of 2020)', 'Avg \n(Mbit/s)Ookla']
for i in columns_plot:
    bar_plot(i)
# Out:
# NO. OF Internet Plans:
# NO. OF Internet Plans
# 60.0    20
# 18.0    11
# 17.0    11
# 21.0    10
# 22.0     9
# 42.0     8
# 13.0     8
# 9.0      7
# 35.0     7
# 19.0     7
# 14.0     7
# 27.0     6
# 24.0     6
# 20.0     6
# 11.0     6
# 15.0     6
# 25.0     5
# 16.0     5
# 23.0     5
# 3.0      4
# 7.0      4
# 12.0     4
# 30.0     4
# 4.0      4
# 45.0     4
# 34.0     4
# 58.0     3
# 36.0     3
# 2.0      3
# 40.0     3
# 28.0     3
# 52.0     3
# 33.0     2
# 31.0     2
# 37.0     2
# 8.0      2
# 32.0     2
# 5.0      2
# 29.0     2
# 6.0      2
# 46.0     2
# 44.0     2
# 59.0     1
# 54.0     1
# 48.0     1
# 50.0     1
# 26.0     1
# 38.0     1
# 47.0     1
# 49.0     1
# 53.0     1
# 39.0     1
# 10.0     1
# 51.0     1
# 1.0      1
# Name: count, dtype: int64
# Average price of 1GB (USD):
# Average price of 1GB (USD)
# 0.75     3
# 2.12     3
# 4.44     3
# 0.60     3
# 0.88     3
#         ..
# 1.77     1
# 1.82     1
# 1.90     1
# 1.93     1
# 49.67    1
# ...

# %%
df.columns
# Out:
# Index(['S.NO', 'NO. OF Internet Plans', 'Average price of 1GB (USD)',
#        'Cheapest 1GB for 30 days (USD)', 'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)', 'Internet users',
#        'Population', 'Avg \n(Mbit/s)Ookla'],
#       dtype='object')

# %%
plt.subplot(3,2,1)
plt.title('NO. OF Internet Plans')
plt.hist(df['NO. OF Internet Plans'])
plt.subplot(3,2,2)
plt.title('Average price of 1GB (USD)')
plt.hist(df['Average price of 1GB (USD)'])
plt.subplot(3,2,5)
plt.title('Cheapest 1GB for 30 days (USD)')
plt.hist(df['Cheapest 1GB for 30 days (USD)'])
plt.subplot(3,2,6)
plt.title('Most expensive 1GB (USD)')
plt.hist(df['Most expensive 1GB (USD)'])
plt.show()

# %%
plt.subplot(3,2,1)
plt.title('Average price of 1GB (USD  at the start of 2021)')
plt.hist(df['Average price of 1GB (USD  at the start of 2021)'])
plt.subplot(3,2,2)
plt.title('Average price of 1GB (USD)')
plt.hist(df['Average price of 1GB (USD)'])
plt.subplot(3,2,5)
plt.title('Average price of 1GB (USD at the start of 2021)')
plt.hist(df['Average price of 1GB (USD  at the start of 2021)'])
plt.subplot(3,2,6)
plt.title('Internet users')
plt.hist(df['Internet users'])
plt.show()

# %%
plt.subplot(3,2,1)
plt.title('Population')
plt.hist(df['Population'])
plt.subplot(3,2,2)
plt.title('Avg \n(Mbit/s)Ookla')
plt.hist(df['Avg \n(Mbit/s)Ookla'])
plt.show()

# %%
df.columns
# Out:
# Index(['S.NO', 'NO. OF Internet Plans', 'Average price of 1GB (USD)',
#        'Cheapest 1GB for 30 days (USD)', 'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)', 'Internet users',
#        'Population', 'Avg \n(Mbit/s)Ookla'],
#       dtype='object')

# %%
sns.boxplot(df['NO. OF Internet Plans'])
# Out:
# <Axes: ylabel='NO. OF Internet Plans'>

# %%
sns.boxplot(df['Average price of 1GB (USD)'])
# Out:
# <Axes: ylabel='Average price of 1GB (USD)'>

# %%
sns.boxplot(df['Cheapest 1GB for 30 days (USD)'])
# Out:
# <Axes: ylabel='Cheapest 1GB for 30 days (USD)'>

# %%
sns.boxplot(df['Most expensive 1GB (USD)'])
# Out:
# <Axes: ylabel='Most expensive 1GB (USD)'>

# %%
sns.boxplot(df['Average price of 1GB (USD  at the start of 2021)'])
# Out:
# <Axes: ylabel='Average price of 1GB (USD  at the start of 2021)'>

# %%
sns.boxplot(df['Average price of 1GB (USD – at start of 2020)'])
# Out:
# <Axes: ylabel='Average price of 1GB (USD – at start of 2020)'>

# %%
sns.boxplot(df['Internet users'])
# Out:
# <Axes: ylabel='Internet users'>

# %%
sns.boxplot(df['Population'])
# Out:
# <Axes: ylabel='Population'>

# %%
sns.boxplot(df['Avg \n(Mbit/s)Ookla'])
# Out:
# <Axes: ylabel='Avg \n(Mbit/s)Ookla'>

# %%
df['Average price of 1GB (USD)']=df['Average price of 1GB (USD)'].fillna(df['Average price of 1GB (USD)'].median())

# %%
df['Cheapest 1GB for 30 days (USD)']=df['Cheapest 1GB for 30 days (USD)'].fillna(df['Cheapest 1GB for 30 days (USD)'].median())

# %%
df['Most expensive 1GB (USD)']=df['Most expensive 1GB (USD)'].fillna(df['Most expensive 1GB (USD)'].median())

# %%
df['Average price of 1GB (USD  at the start of 2021)']=df['Average price of 1GB (USD  at the start of 2021)'].fillna(df['Average price of 1GB (USD  at the start of 2021)'].median())

# %%
df['Average price of 1GB (USD – at start of 2020)']=df['Average price of 1GB (USD – at start of 2020)'].fillna(df['Average price of 1GB (USD – at start of 2020)'].median())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 df['Average price of 1GB (USD – at start of 2020)']=df['Average price of 1GB (USD – at start of 2020)'].fillna(df['Average price of 1GB (USD – at start of 2020)'].median())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6559, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6551 @doc(make_doc("median", ndim=1))
#    6552 def median(
#    6553     self,
#    (...)
#    6557     **kwargs,
#    6558 ):
# -> 6559     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
#   12429     **kwargs,
#   12430 ) -> Series | float:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229 entries, 0 to 230
# Data columns (total 10 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   S.NO                                              229 non-null    int64
#  1   NO. OF Internet Plans                             229 non-null    float64
#  2   Average price of 1GB (USD)                        229 non-null    float64
#  3   Cheapest 1GB for 30 days (USD)                    229 non-null    float64
#  4   Most expensive 1GB (USD)                          229 non-null    float64
#  5   Average price of 1GB (USD  at the start of 2021)  229 non-null    float64
#  6   Average price of 1GB (USD – at start of 2020)     229 non-null    object
#  7   Internet users                                    204 non-null    float64
#  8   Population                                        202 non-null    float64
# ...

# %%
target_element='NO PACKAGES'
mask=df['Average price of 1GB (USD – at start of 2020)'] != target_element
df=df[mask]

# %%
df['Average price of 1GB (USD – at start of 2020)']=df['Average price of 1GB (USD – at start of 2020)'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 226 entries, 0 to 230
# Data columns (total 10 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   S.NO                                              226 non-null    int64
#  1   NO. OF Internet Plans                             226 non-null    float64
#  2   Average price of 1GB (USD)                        226 non-null    float64
#  3   Cheapest 1GB for 30 days (USD)                    226 non-null    float64
#  4   Most expensive 1GB (USD)                          226 non-null    float64
#  5   Average price of 1GB (USD  at the start of 2021)  226 non-null    float64
#  6   Average price of 1GB (USD – at start of 2020)     226 non-null    float64
#  7   Internet users                                    202 non-null    float64
#  8   Population                                        200 non-null    float64
# ...

# %%
df['Average price of 1GB (USD – at start of 2020)']=df['Average price of 1GB (USD – at start of 2020)'].fillna(df['Average price of 1GB (USD – at start of 2020)'].median())

# %%
df['Internet users']=df['Internet users'].fillna(df['Internet users'].median())

# %%
df['Population']=df['Population'].fillna(df['Population'].median())

# %%
df['Avg \n(Mbit/s)Ookla']=df['Avg \n(Mbit/s)Ookla'].fillna(df['Avg \n(Mbit/s)Ookla'].median())

# %%
df.isnull().sum()
# Out:
# S.NO                                                0
# NO. OF Internet Plans                               0
# Average price of 1GB (USD)                          0
# Cheapest 1GB for 30 days (USD)                      0
# Most expensive 1GB (USD)                            0
# Average price of 1GB (USD  at the start of 2021)    0
# Average price of 1GB (USD – at start of 2020)       0
# Internet users                                      0
# Population                                          0
# Avg \n(Mbit/s)Ookla                                 0
# dtype: int64

# %%
sns.heatmap(df.corr(),annot=True,fmt='.2f')
plt.show()
